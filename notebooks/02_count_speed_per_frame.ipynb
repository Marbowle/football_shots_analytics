# %% [markdown]
# Count number of frames and speed to calculate speed

# %%
import cv2

# %%
video_path = "D:/football_shots_analytics/data/clips/match_shorts/bundesliga.mp4"
cap = cv2.VideoCapture(video_path)

# %%
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

fps = cap.get(cv2.CAP_PROP_FPS)

duration = total_frames / fps

# %%
print(f"Liczba klatek {total_frames}")
print(f"FPS {fps}")
print(f"Czas trwania {duration}")
# Out:
# Liczba klatek 750
# FPS 25.0
# Czas trwania 30.0

# %% [markdown]
# ## Calculate distance and metrcis

# %%
import pandas as pd

# %%
FPS = int(fps)

# %%
data_path = "D:/football_shots_analytics/outputs/distance_summary.csv"

# %%
df = pd.read_csv(data_path)

# %%
df.head()
# Out:
#    Unnamed: 0  track_id  total_distance_px  frames_tracked
# 0           0         0          1743.6291             654
# 1           1         1          2270.6592             749
# 2           2         2           784.5194             273
# 3           3         3         13365.8840             868
# 4           4         4           771.2260             166

# %%
duration_s = duration

# %%
df['duration_s'] = df['frames_tracked'] / FPS

# %%
df['avg_speed_px_s'] = df['total_distance_px']/df['duration_s']

# %%
df.head()
# Out:
#    Unnamed: 0  track_id  total_distance_px  frames_tracked  duration_s  \
# 0           0         0          1743.6291             654       26.16
# 1           1         1          2270.6592             749       29.96
# 2           2         2           784.5194             273       10.92
# 3           3         3         13365.8840             868       34.72
# 4           4         4           771.2260             166        6.64
#
#    avg_speed_px_s
# 0       66.652489
# 1       75.789693
# 2       71.842436
# 3      384.962097
# 4      116.148494
